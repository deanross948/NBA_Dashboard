# %%
import pandas as pd
import requests
pd.set_option('display.max_columns', None)
import time
import numpy as np

# %%
test_url = 'https://stats.nba.com/stats/leagueLeaders?LeagueID=00&PerMode=PerGame&Scope=S&Season=2024-25&SeasonType=Regular%20Season&StatCategory=PTS'

# %%
r = requests.get(url=test_url).json()

# %%
table_headers = r['resultSet']['headers']

# %%
pd.DataFrame(r['resultSet']['rowSet'], columns=table_headers)
# Out:
#      PLAYER_ID  RANK                   PLAYER     TEAM_ID TEAM  GP   MIN  \
# 0      1628983     1  Shai Gilgeous-Alexander  1610612760  OKC  71  34.3
# 1       203507     2    Giannis Antetokounmpo  1610612749  MIL  61  33.9
# 2       203999     3             Nikola Jokić  1610612743  DEN  64  36.5
# 3      1630162     4          Anthony Edwards  1610612750  MIN  72  36.2
# 4      1628369     5             Jayson Tatum  1610612738  BOS  67  36.4
# ..         ...   ...                      ...         ...  ...  ..   ...
# 236     203500   237             Steven Adams  1610612745  HOU  54  13.4
# 237    1642345   238             Oso Ighodaro  1610612756  PHX  54  16.1
# 238    1641748   239        Andre Jackson Jr.  1610612749  MIL  62  14.9
# 239    1630192   240               Zeke Nnaji  1610612743  DEN  53  10.6
# 240    1630579   241             Jericho Sims  1610612749  MIL  53  11.9
#
#       FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM   FTA  FT_PCT  OREB  DREB  \
# 0    11.3  21.8   0.521   2.1   5.7    0.372  8.1   9.0   0.900   0.9   4.2
# 1    11.9  19.8   0.601   0.1   0.8    0.176  6.3  10.5   0.605   2.3   9.6
# 2    11.2  19.4   0.574   1.9   4.6    0.412  5.0   6.3   0.803   2.9   9.9
# 3     9.0  20.3   0.441   4.0  10.1    0.395  5.3   6.3   0.839   0.8   4.9
# 4     9.3  20.4   0.455   3.6  10.1    0.351  5.0   6.2   0.813   0.7   8.0
# ..    ...   ...     ...   ...   ...      ...  ...   ...     ...   ...   ...
# 236   1.5   2.8   0.546   0.0   0.0    0.000  0.8   1.7   0.451   2.9   2.6
# 237   1.6   2.8   0.597   0.0   0.0    0.000  0.5   0.9   0.596   0.9   2.6
# 238   1.4   3.0   0.465   0.5   1.2    0.387  0.2   0.4   0.545   1.0   1.8
# 239   1.3   2.5   0.507   0.3   0.9    0.333  0.4   0.7   0.605   0.6   1.0
# 240   0.8   1.3   0.634   0.0   0.0    0.000  0.2   0.2   0.615   1.3   2.4
#
#       REB   AST  STL  BLK  TOV   PTS   EFF
# 0     5.1   6.3  1.7  1.0  2.5  32.9  33.2
# 1    11.9   5.9  0.8  1.2  3.2  30.2  34.9
# 2    12.8  10.2  1.8  0.7  3.3  29.3  41.9
# 3     5.7   4.6  1.1  0.6  3.2  27.2  23.6
# 4     8.7   6.0  1.1  0.5  3.0  27.2  28.2
# ..    ...   ...  ...  ...  ...   ...   ...
# 236   5.4   1.2  0.4  0.5  0.9   3.8   8.1
# 237   3.5   1.1  0.4  0.4  0.6   3.8   7.2
# 238   2.8   1.3  0.5  0.2  0.9   3.5   5.7
# 239   1.6   0.4  0.4  0.7  0.2   3.3   4.7
# 240   3.7   0.6  0.2  0.4  0.6   1.8   5.5
#
# [241 rows x 25 columns]

# %%
temp_df1 = pd.DataFrame(r['resultSet']['rowSet'], columns=table_headers)
temp_df2 = pd.DataFrame({'Year':['2012-13' for i in range(len(temp_df1))],
                         'Season_type':['Regular%20Season' for i in range(len(temp_df1))]})
temp_df3 = pd.concat([temp_df2,temp_df1], axis=1)
temp_df3
# Out:
#         Year       Season_type  PLAYER_ID  RANK                   PLAYER  \
# 0    2012-13  Regular%20Season    1628983     1  Shai Gilgeous-Alexander
# 1    2012-13  Regular%20Season     203507     2    Giannis Antetokounmpo
# 2    2012-13  Regular%20Season     203999     3             Nikola Jokić
# 3    2012-13  Regular%20Season    1630162     4          Anthony Edwards
# 4    2012-13  Regular%20Season    1628369     5             Jayson Tatum
# ..       ...               ...        ...   ...                      ...
# 236  2012-13  Regular%20Season     203500   237             Steven Adams
# 237  2012-13  Regular%20Season    1642345   238             Oso Ighodaro
# 238  2012-13  Regular%20Season    1641748   239        Andre Jackson Jr.
# 239  2012-13  Regular%20Season    1630192   240               Zeke Nnaji
# 240  2012-13  Regular%20Season    1630579   241             Jericho Sims
#
#         TEAM_ID TEAM  GP   MIN   FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  \
# 0    1610612760  OKC  71  34.3  11.3  21.8   0.521   2.1   5.7    0.372  8.1
# 1    1610612749  MIL  61  33.9  11.9  19.8   0.601   0.1   0.8    0.176  6.3
# 2    1610612743  DEN  64  36.5  11.2  19.4   0.574   1.9   4.6    0.412  5.0
# 3    1610612750  MIN  72  36.2   9.0  20.3   0.441   4.0  10.1    0.395  5.3
# 4    1610612738  BOS  67  36.4   9.3  20.4   0.455   3.6  10.1    0.351  5.0
# ..          ...  ...  ..   ...   ...   ...     ...   ...   ...      ...  ...
# 236  1610612745  HOU  54  13.4   1.5   2.8   0.546   0.0   0.0    0.000  0.8
# 237  1610612756  PHX  54  16.1   1.6   2.8   0.597   0.0   0.0    0.000  0.5
# 238  1610612749  MIL  62  14.9   1.4   3.0   0.465   0.5   1.2    0.387  0.2
# 239  1610612743  DEN  53  10.6   1.3   2.5   0.507   0.3   0.9    0.333  0.4
# 240  1610612749  MIL  53  11.9   0.8   1.3   0.634   0.0   0.0    0.000  0.2
#
#       FTA  FT_PCT  OREB  DREB   REB   AST  STL  BLK  TOV   PTS   EFF
# 0     9.0   0.900   0.9   4.2   5.1   6.3  1.7  1.0  2.5  32.9  33.2
# 1    10.5   0.605   2.3   9.6  11.9   5.9  0.8  1.2  3.2  30.2  34.9
# 2     6.3   0.803   2.9   9.9  12.8  10.2  1.8  0.7  3.3  29.3  41.9
# 3     6.3   0.839   0.8   4.9   5.7   4.6  1.1  0.6  3.2  27.2  23.6
# 4     6.2   0.813   0.7   8.0   8.7   6.0  1.1  0.5  3.0  27.2  28.2
# ..    ...     ...   ...   ...   ...   ...  ...  ...  ...   ...   ...
# 236   1.7   0.451   2.9   2.6   5.4   1.2  0.4  0.5  0.9   3.8   8.1
# 237   0.9   0.596   0.9   2.6   3.5   1.1  0.4  0.4  0.6   3.8   7.2
# 238   0.4   0.545   1.0   1.8   2.8   1.3  0.5  0.2  0.9   3.5   5.7
# 239   0.7   0.605   0.6   1.0   1.6   0.4  0.4  0.7  0.2   3.3   4.7
# 240   0.2   0.615   1.3   2.4   3.7   0.6  0.2  0.4  0.6   1.8   5.5
#
# [241 rows x 27 columns]

# %%
del temp_df1, temp_df2, temp_df3

# %%
df_cols = ['Year','Season_type'] + table_headers

# %%
pd.DataFrame(columns=df_cols)
# Out:
# Empty DataFrame
# Columns: [Year, Season_type, PLAYER_ID, RANK, PLAYER, TEAM_ID, TEAM, GP, MIN, FGM, FGA, FG_PCT, FG3M, FG3A, FG3_PCT, FTM, FTA, FT_PCT, OREB, DREB, REB, AST, STL, BLK, TOV, PTS, EFF]
# Index: []

# %%
headers = {
    'accept': '*/*'
    'accept-encoding': 'gzip, deflate, br, zstd'
    'accept-language': 'en-US,en;q=0.9'
    'connection':'keep-alive'
    'host':'stats.nba.com'
    'origin':'https://www.nba.com'
    'referer':'https://www.nba.com/'
    'sec-ch-ua':'"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"'
    'sec-ch-ua-mobile':'?0'
    'sec-ch-ua-platform':"Windows"
    'sec-fetch-dest':'empty'
    'sec-fetch-mode':'cors'
    'sec-fetch-site':'same-site'
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36'

# %%
df = pd.DataFrame(columns=df_cols)
season_types = ['Regular%20Season', 'Playoffs']
years = ['2015-16','2016-17','2017-18','2018-19','2019-20','2020-21','2021-22','2022-23','2023-24','2024-25']

begin_loop = time.time()

for y in years:
    for s in season_types:
        api_url = 'https://stats.nba.com/stats/leagueLeaders?LeagueID=00&PerMode=PerGame&Scope=S&Season='+y+'&SeasonType='+s+'&StatCategory=PTS'
        r = requests.get(url=api_url).json()
        temp_df1 = pd.DataFrame(r['resultSet']['rowSet'], columns=table_headers)
        temp_df2 = pd.DataFrame({'Year':[y for i in range(len(temp_df1))],
                                 'Season_type':[s for i in range(len(temp_df1))]})
        temp_df3 = pd.concat([temp_df2,temp_df1], axis=1)
        df = pd.concat([df,temp_df3], axis=0)
        print(f'Finished scraping data for the {y} {s}.')
        lag = np.random.uniform(low=5,high=20)
        print(f'...waiting {round(lag,1)} seconds')
        time.sleep(lag)

print(f'process completed! Total run time: {round((time.time()-begin_loop)/60,2)}')
df.to_excel('nba_player_data.xlsx', index=False)
# Out:
# C:\Users\Dean\AppData\Local\Temp\ipykernel_43924\2578113190.py:15: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df,temp_df3], axis=0)
# Finished scraping data for the 2015-16 Regular%20Season.
# ...waiting 8.1 seconds
# Finished scraping data for the 2015-16 Playoffs.
# ...waiting 11.3 seconds
# Finished scraping data for the 2016-17 Regular%20Season.
# ...waiting 16.2 seconds
# Finished scraping data for the 2016-17 Playoffs.
# ...waiting 10.8 seconds
# Finished scraping data for the 2017-18 Regular%20Season.
# ...waiting 15.7 seconds
# Finished scraping data for the 2017-18 Playoffs.
# ...waiting 15.3 seconds
# Finished scraping data for the 2018-19 Regular%20Season.
# ...waiting 15.4 seconds
# Finished scraping data for the 2018-19 Playoffs.
# ...waiting 5.5 seconds
# Finished scraping data for the 2019-20 Regular%20Season.
# ...waiting 10.9 seconds
# Finished scraping data for the 2019-20 Playoffs.
# ...waiting 15.5 seconds
# Finished scraping data for the 2020-21 Regular%20Season.
# ...waiting 7.8 seconds
# Finished scraping data for the 2020-21 Playoffs.
# ...waiting 6.5 seconds
# Finished scraping data for the 2021-22 Regular%20Season.
# ...waiting 17.8 seconds
# Finished scraping data for the 2021-22 Playoffs.
# ...waiting 19.8 seconds
# Finished scraping data for the 2022-23 Regular%20Season.
# ...waiting 7.7 seconds
# Finished scraping data for the 2022-23 Playoffs.
# ...waiting 7.8 seconds
# Finished scraping data for the 2023-24 Regular%20Season.
# ...waiting 17.1 seconds
# Finished scraping data for the 2023-24 Playoffs.
# ...waiting 7.8 seconds
# Finished scraping data for the 2024-25 Regular%20Season.
# ...waiting 12.6 seconds
# C:\Users\Dean\AppData\Local\Temp\ipykernel_43924\2578113190.py:15: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df,temp_df3], axis=0)
# Finished scraping data for the 2024-25 Playoffs.
# ...waiting 9.9 seconds
# process completed! Total run time: 4.02

# %%
df
# Out:
#         Year       Season_type PLAYER_ID RANK             PLAYER     TEAM_ID  \
# 0    2015-16  Regular%20Season    201939    1      Stephen Curry  1610612744
# 1    2015-16  Regular%20Season    201935    2       James Harden  1610612745
# 2    2015-16  Regular%20Season    201142    3       Kevin Durant  1610612760
# 3    2015-16  Regular%20Season    202326    4   DeMarcus Cousins  1610612758
# 4    2015-16  Regular%20Season      2544    5       LeBron James  1610612739
# ..       ...               ...       ...  ...                ...         ...
# 236  2024-25  Regular%20Season    201587  237      Nicolas Batum  1610612746
# 237  2024-25  Regular%20Season   1642345  238       Oso Ighodaro  1610612756
# 238  2024-25  Regular%20Season   1641748  239  Andre Jackson Jr.  1610612749
# 239  2024-25  Regular%20Season   1630192  240         Zeke Nnaji  1610612743
# 240  2024-25  Regular%20Season   1630579  241       Jericho Sims  1610612749
#
#     TEAM  GP   MIN   FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM   FTA  \
# 0    GSW  79  34.2  10.2  20.2   0.504   5.1  11.2    0.454  4.6   5.1
# 1    HOU  82  38.1   8.7  19.7   0.439   2.9   8.0    0.359  8.8  10.2
# 2    OKC  72  35.8   9.7  19.2   0.505   2.6   6.7    0.387  6.2   6.9
# 3    SAC  65  34.6   9.2  20.5   0.451   1.1   3.2    0.333  7.3  10.2
# 4    CLE  76  35.6   9.7  18.6   0.520   1.1   3.7    0.309  4.7   6.5
# ..   ...  ..   ...   ...   ...     ...   ...   ...      ...  ...   ...
# 236  LAC  73  17.8   1.3   3.0   0.423   1.1   2.5    0.419  0.2   0.3
# 237  PHX  54  16.1   1.6   2.8   0.597   0.0   0.0    0.000  0.5   0.9
# 238  MIL  62  14.9   1.4   3.0   0.465   0.5   1.2    0.387  0.2   0.4
# 239  DEN  53  10.6   1.3   2.5   0.507   0.3   0.9    0.333  0.4   0.7
# 240  MIL  53  11.9   0.8   1.3   0.634   0.0   0.0    0.000  0.2   0.2
#
#      FT_PCT  OREB  DREB   REB  AST  STL  BLK  TOV   PTS   EFF
# 0     0.908   0.9   4.6   5.4  6.7  2.1  0.2  3.3  30.1  30.7
# 1     0.860   0.8   5.3   6.1  7.5  1.7  0.6  4.6  29.0  27.8
# 2     0.898   0.6   7.6   8.2  5.0  1.0  1.2  3.5  28.2  29.8
# 3     0.718   2.4   9.1  11.5  3.3  1.6  1.4  3.8  26.9  26.7
# 4     0.731   1.5   6.0   7.4  6.8  1.4  0.6  3.3  25.3  27.5
# ..      ...   ...   ...   ...  ...  ...  ...  ...   ...   ...
# 236   0.800   0.6   2.2   2.8  1.1  0.7  0.5  0.4   3.8   6.7
# 237   0.596   0.9   2.6   3.5  1.1  0.4  0.4  0.6   3.8   7.2
# 238   0.545   1.0   1.8   2.8  1.3  0.5  0.2  0.9   3.5   5.7
# 239   0.605   0.6   1.0   1.6  0.4  0.4  0.7  0.2   3.3   4.7
# 240   0.615   1.3   2.4   3.7  0.6  0.2  0.4  0.6   1.8   5.5
#
# [3846 rows x 27 columns]
